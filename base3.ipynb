# %%
import run_simulation as rs
import numpy as np	
import matplotlib.pyplot as plt
# Out:
# C:\Users\cordo\AppData\Roaming\Python\Python310\site-packages\cupyx\jit\_interface.py:173: FutureWarning: cupyx.jit.rawkernel is experimental. The interface can change in the future.
#   cupy._util.experimental('cupyx.jit.rawkernel')

# %%
rs.check_system()
# Out:
# GPU is available
# GPU:  b'NVIDIA GeForce RTX 4070 SUPER'

# %%
xi=0.1
sizes=[0.6,1.0,1.6]



devices_list=[]

for size in sizes:
	devices_list.append(rs.define_4_terminal_mesh(size,size,xi=xi, probes=[((-size*(0.4),0),
					   				(size*(0.4),0),
									)]))

fig,ax=devices_list[-1].draw()

# %%
fig,ax=devices_list[0].draw()

# %%
for device in devices_list:
	rs.build_mesh(device,max_edge_L=xi/4,plot=False)
# Out:
# Constructing Voronoi polygons: 100%|██████████| 2680/2680 [00:01<00:00, 1493.75it/s]
# min_edge_length: 3.642e-03
# max_edge_length: 2.457e-02
# mean_edge_length: 1.226e-02
# min_area: 8.219e-06
# max_area: 3.710e-04
# mean_area: 1.343e-04
# coherence_length: 1.000e-01
# Constructing Voronoi polygons: 100%|██████████| 5730/5730 [00:03<00:00, 1590.23it/s]
# min_edge_length: 6.177e-03
# max_edge_length: 2.563e-02
# mean_edge_length: 1.440e-02
# min_area: 2.309e-05
# max_area: 3.865e-04
# mean_area: 1.745e-04
# coherence_length: 1.000e-01
# Constructing Voronoi polygons: 100%|██████████| 13836/13836 [00:07<00:00, 1803.30it/s]
# min_edge_length: 6.875e-03
# max_edge_length: 2.652e-02
# mean_edge_length: 1.478e-02
# min_area: 4.907e-05
# max_area: 3.826e-04
# mean_area: 1.850e-04
# coherence_length: 1.000e-01

# %%
solutions_list=[]
currents_list=[]

for device in devices_list:
	print("--------------------------------------------------------------------------------")
	solutions,currents=rs.current_series(device,0,30,25,0,solve_time=100)
	solutions_list.append(solutions)
	currents_list.append(currents)
# Out:
# --------------------------------------------------------------------------------
# Simulating: 100%|█████████▉| 200/200 [00:40<00:00,  4.92tau/s ]
# 1/25 done
# Simulating: 100%|█████████▉| 200/200 [01:01<00:00,  3.27tau/s ]
# 2/25 done
# Simulating: 100%|█████████▉| 200/200 [01:00<00:00,  3.32tau/s ]
# 3/25 done
# Simulating: 100%|█████████▉| 200/200 [00:55<00:00,  3.62tau/s ]
# 4/25 done
# Simulating: 100%|█████████▉| 200/200 [00:53<00:00,  3.77tau/s ]
# 5/25 done
# Simulating: 100%|█████████▉| 200/200 [00:53<00:00,  3.77tau/s ]
# 6/25 done
# Simulating: 100%|█████████▉| 200/200 [00:51<00:00,  3.91tau/s ]
# 7/25 done
# Simulating: 100%|█████████▉| 200/200 [00:48<00:00,  4.15tau/s ]
# 8/25 done
# Simulating: 100%|█████████▉| 200/200 [00:48<00:00,  4.13tau/s ]
# 9/25 done
# Simulating: 100%|█████████▉| 200/200 [00:49<00:00,  4.04tau/s ]
# 10/25 done
# Simulating: 100%|█████████▉| 200/200 [00:49<00:00,  4.05tau/s ]
# 11/25 done
# Simulating: 100%|█████████▉| 200/200 [00:49<00:00,  4.04tau/s ]
# 12/25 done
# Simulating: 100%|█████████▉| 200/200 [00:48<00:00,  4.12tau/s ]
# 13/25 done
# Simulating: 100%|█████████▉| 200/200 [00:46<00:00,  4.29tau/s ]
# 14/25 done
# Simulating: 100%|█████████▉| 200/200 [00:46<00:00,  4.34tau/s ]
# 15/25 done
# Simulating: 100%|█████████▉| 200/200 [00:45<00:00,  4.35tau/s ]
# 16/25 done
# Simulating: 100%|█████████▉| 200/200 [00:46<00:00,  4.30tau/s ]
# 17/25 done
# Simulating: 100%|█████████▉| 200/200 [00:45<00:00,  4.37tau/s ]
# 18/25 done
# Simulating: 100%|█████████▉| 200/200 [00:47<00:00,  4.23tau/s ]
# 19/25 done
# Simulating: 100%|█████████▉| 200/200 [00:45<00:00,  4.36tau/s ]
# 20/25 done
# Simulating: 100%|█████████▉| 200/200 [00:46<00:00,  4.31tau/s ]
# 21/25 done
# Simulating: 100%|█████████▉| 200/200 [00:45<00:00,  4.42tau/s ]
# 22/25 done
# Simulating: 100%|█████████▉| 200/200 [00:45<00:00,  4.42tau/s ]
# 23/25 done
# Simulating: 100%|█████████▉| 200/200 [00:47<00:00,  4.25tau/s ]
# 24/25 done
# Simulating: 100%|█████████▉| 200/200 [00:46<00:00,  4.32tau/s ]
# 25/25 done
# --------------------------------------------------------------------------------
# Simulating: 100%|█████████▉| 200/200 [00:22<00:00,  8.75tau/s ]
# 1/25 done
# Simulating: 100%|█████████▉| 200/200 [00:51<00:00,  3.85tau/s ]
# 2/25 done
# Simulating: 100%|█████████▉| 200/200 [00:55<00:00,  3.58tau/s ]
# 3/25 done
# Simulating: 100%|█████████▉| 200/200 [00:53<00:00,  3.72tau/s ]
# 4/25 done
# Simulating: 100%|█████████▉| 200/200 [00:55<00:00,  3.63tau/s ]
# 5/25 done
# Simulating: 100%|█████████▉| 200/200 [00:58<00:00,  3.42tau/s ]
# 6/25 done
# Simulating: 100%|█████████▉| 200/200 [00:58<00:00,  3.44tau/s ]
# 7/25 done
# Simulating: 100%|█████████▉| 200/200 [00:59<00:00,  3.39tau/s ]
# 8/25 done
# Simulating: 100%|█████████▉| 200/200 [00:58<00:00,  3.39tau/s ]
# 9/25 done
# Simulating: 100%|█████████▉| 200/200 [01:07<00:00,  2.98tau/s ]
# 10/25 done
# Simulating: 100%|█████████▉| 200/200 [01:01<00:00,  3.27tau/s ]
# 11/25 done
# Simulating: 100%|█████████▉| 200/200 [00:50<00:00,  3.97tau/s ]
# 12/25 done
# Simulating: 100%|█████████▉| 200/200 [00:50<00:00,  3.99tau/s ]
# 13/25 done
# Simulating: 100%|█████████▉| 200/200 [00:49<00:00,  4.07tau/s ]
# 14/25 done
# Simulating: 100%|█████████▉| 200/200 [00:47<00:00,  4.17tau/s ]
# 15/25 done
# Simulating: 100%|█████████▉| 200/200 [00:50<00:00,  3.97tau/s ]
# 16/25 done
# Simulating: 100%|█████████▉| 200/200 [00:50<00:00,  3.95tau/s ]
# 17/25 done
# Simulating: 100%|█████████▉| 200/200 [00:51<00:00,  3.89tau/s ]
# 18/25 done
# Simulating: 100%|█████████▉| 200/200 [00:49<00:00,  4.00tau/s ]
# 19/25 done
# Simulating: 100%|█████████▉| 200/200 [00:52<00:00,  3.80tau/s ]
# 20/25 done
# Simulating: 100%|█████████▉| 200/200 [00:51<00:00,  3.85tau/s ]
# 21/25 done
# Simulating: 100%|█████████▉| 200/200 [00:52<00:00,  3.81tau/s ]
# 22/25 done
# Simulating: 100%|█████████▉| 200/200 [00:51<00:00,  3.89tau/s ]
# 23/25 done
# Simulating: 100%|█████████▉| 200/200 [00:52<00:00,  3.80tau/s ]
# 24/25 done
# Simulating: 100%|█████████▉| 200/200 [00:53<00:00,  3.72tau/s ]
# 25/25 done
# --------------------------------------------------------------------------------
# Simulating: 100%|█████████▉| 200/200 [00:49<00:00,  4.06tau/s ]
# 1/25 done
# Simulating: 100%|█████████▉| 200/200 [01:42<00:00,  1.94tau/s ]
# 2/25 done
# Simulating: 100%|█████████▉| 200/200 [01:45<00:00,  1.89tau/s ]
# 3/25 done
# Simulating: 100%|█████████▉| 200/200 [01:42<00:00,  1.94tau/s ]
# 4/25 done
# Simulating: 100%|█████████▉| 200/200 [02:11<00:00,  1.52tau/s ]
# 5/25 done
# Simulating: 100%|█████████▉| 200/200 [01:55<00:00,  1.74tau/s ]
# 6/25 done
# Simulating: 100%|█████████▉| 200/200 [01:31<00:00,  2.19tau/s ]
# 7/25 done
# Simulating: 100%|█████████▉| 200/200 [01:26<00:00,  2.30tau/s ]
# 8/25 done
# Simulating: 100%|█████████▉| 200/200 [01:20<00:00,  2.47tau/s ]
# 9/25 done
# Simulating: 100%|█████████▉| 200/200 [01:21<00:00,  2.47tau/s ]
# 10/25 done
# Simulating: 100%|█████████▉| 200/200 [01:25<00:00,  2.34tau/s ]
# 11/25 done
# Simulating: 100%|█████████▉| 200/200 [01:24<00:00,  2.38tau/s ]
# 12/25 done
# Simulating: 100%|█████████▉| 200/200 [01:22<00:00,  2.42tau/s ]
# 13/25 done
# Simulating: 100%|█████████▉| 200/200 [01:22<00:00,  2.41tau/s ]
# 14/25 done
# Simulating: 100%|█████████▉| 200/200 [01:22<00:00,  2.43tau/s ]
# 15/25 done
# Simulating: 100%|█████████▉| 200/200 [01:30<00:00,  2.22tau/s ]
# 16/25 done
# Simulating: 100%|█████████▉| 200/200 [02:43<00:00,  1.22tau/s ]
# 17/25 done
# Simulating: 100%|█████████▉| 200/200 [02:23<00:00,  1.40tau/s ]
# 18/25 done
# Simulating: 100%|█████████▉| 200/200 [02:08<00:00,  1.56tau/s ]
# 19/25 done
# Simulating: 100%|█████████▉| 200/200 [02:07<00:00,  1.57tau/s ]
# 20/25 done
# Simulating: 100%|█████████▉| 200/200 [02:01<00:00,  1.64tau/s ]
# 21/25 done
# Simulating: 100%|█████████▉| 200/200 [01:58<00:00,  1.68tau/s ]
# 22/25 done
# Simulating: 100%|█████████▉| 200/200 [02:01<00:00,  1.65tau/s ]
# 23/25 done
# Simulating: 100%|█████████▉| 200/200 [01:59<00:00,  1.67tau/s ]
# 24/25 done
# Simulating: 100%|█████████▉| 200/200 [02:08<00:00,  1.56tau/s ]
# 25/25 done

# %%
jj=0
voltages_for_squares=[]
for solutions in solutions_list:
	ii=0
	voltages_list=[]
	voltage_values=np.zeros(len(solutions))
	for solution in solutions:
		voltages_list.append(solution.dynamics.voltage())
		max_idx=voltages_list[ii].shape[0]-1
		voltage_values[ii]=np.mean(voltages_list[ii][max_idx-5000:max_idx])
		print(voltage_values[ii])

		ii+=1
	voltages_for_squares.append(voltages_list)


	plt.plot(currents_list[jj],voltage_values, label=f'{sizes[jj]}$\mu m$')
	jj+=1

plt.legend()
# plt.xlim(0,6)
# plt.ylim(0,1)
# Out:
# 0.0
# 0.08197819665607844
# 0.16481340753657026
# 0.24951295040233745
# 0.33767549106043687
# 0.4325078749620067
# 0.548477635563737
# 1.6297823415050106
# 1.8909056484656674
# 2.1451507277106807
# 2.3977438706770173
# 2.6496104791570665
# 2.9001898363588183
# 3.150159198008429
# 3.399459610987999
# 3.6484650940129875
# 3.8970979111146415
# 4.145602072285403
# 4.3936959625170875
# 4.6416579293696065
# 4.889408519649548
# 5.137098241516788
# 5.384640745846467
# 5.6321411057989055
# 5.879442218133282
# 0.0
# 0.027680566742142015
# 0.05560367571517332
# 0.08402162984516724
# 0.11323799543964419
# 0.14361872170846077
# 0.17563277028523402
# 0.2099933986330758
# 0.2478446806532995
# 0.2913507224656629
# 0.3458840653552361
# 2.1594966696154367
# 2.5414547768495557
# 2.827319448251548
# 3.100738112518641
# 3.365183349694706
# 3.6211242566688555
# 3.8717459747755303
# 4.1192772890846765
# 4.365034334393841
# 4.609426049129917
# 4.85280190828733
# 5.095224662561026
# 5.336933168969995
# 5.577948264398132
# 0.0
# 0.008879977115480723
# 0.01784645609052368
# 0.02698917246121113
# 0.03641713256954881
# 0.046239883064921335
# 0.056606398317212404
# 0.06770902187985939
# 0.07979524922135638
# 0.09322012820971454
# 0.10853678659007866
# 0.12661849189489074
# 0.14910708098405115
# 0.17960594676477604
# 0.22887671984831595
# 0.3548122086266293
# 1.8861992898686095
# 3.6774522133160144
# 4.012945475577186
# 4.307684737754384
# 4.591679165707465
# 4.867955726455487
# 5.13983864665485
# 5.407473652110633
# 5.672248355038397

# %%
import matplotlib.cm as cm
colors=['r','g','b','k']
fig, ax = plt.subplots()

cmap = cm.get_cmap('viridis', len(currents))
norm = plt.Normalize(0, len(currents) - 1)
jj=0

for solutions in solutions_list:
	ii=0
	if jj>=1:
		break
	voltages_list=[]
	for solution in solutions:
		solution.dynamics.voltage()
		
		ii+=1





		ax.plot(solution.dynamics.time,solution.dynamics.voltage(),color=cmap(norm(ii)))
	jj+=1

sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
fig.colorbar(sm, ax=ax, orientation='vertical', label='corriente $\mu A$')
ax.set_xlabel(r'Tiempo ($\tau$)')
ax.set_ylabel('Voltaje ($V_0$)')
# Out:
# C:\Users\cordo\AppData\Local\Temp\ipykernel_9256\3276978076.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('viridis', len(currents))
# Text(0, 0.5, 'Voltaje ($V_0$)')
