# %%
import run_simulation as rs
import numpy as np	
import matplotlib.pyplot as plt
# Out:
# C:\Users\cordo\AppData\Roaming\Python\Python310\site-packages\cupyx\jit\_interface.py:173: FutureWarning: cupyx.jit.rawkernel is experimental. The interface can change in the future.
#   cupy._util.experimental('cupyx.jit.rawkernel')

# %%
rs.check_system()
# Out:
# GPU is available
# GPU:  b'NVIDIA GeForce RTX 4070 SUPER'

# %%
xi=0.1
sizes=[0.6]



devices_list=[]

for size in sizes:
	devices_list.append(rs.define_2_terminal_mesh(size,size,xi=xi, probes=[((-size*(0.4),0),
					   				(size*(0.4),0),
									)]))
sizes.append(0.6)
devices_list.append(rs.define_2_terminal_mesh(size*2,size,xi=xi, probes=[((-size*(0.4),0),
					   				(size*(0.4),0),
									)]))
fig,ax=devices_list[-1].draw()

# %%
fig,ax=devices_list[0].draw()

# %%
for device in devices_list:
	rs.build_mesh(device,max_edge_L=xi/4,plot=False)
# Out:
# Constructing Voronoi polygons: 100%|██████████| 2680/2680 [00:01<00:00, 1507.99it/s]
# min_edge_length: 3.642e-03
# max_edge_length: 2.457e-02
# mean_edge_length: 1.226e-02
# min_area: 8.219e-06
# max_area: 3.710e-04
# mean_area: 1.343e-04
# coherence_length: 1.000e-01
# Constructing Voronoi polygons: 100%|██████████| 4154/4154 [00:02<00:00, 1630.62it/s]
# min_edge_length: 5.693e-03
# max_edge_length: 2.500e-02
# mean_edge_length: 1.433e-02
# min_area: 1.765e-05
# max_area: 3.765e-04
# mean_area: 1.733e-04
# coherence_length: 1.000e-01

# %%
solutions_list=[]
currents_list=[]

for device in devices_list:
	print("--------------------------------------------------------------------------------")
	solutions,currents=rs.current_series(device,0,30,25,0,solve_time=100)
	solutions_list.append(solutions)
	currents_list.append(currents)
# Out:
# --------------------------------------------------------------------------------
# Simulating: 100%|█████████▉| 200/200 [00:40<00:00,  4.99tau/s ]
# 1/25 done
# Simulating: 100%|█████████▉| 200/200 [01:02<00:00,  3.19tau/s ]
# 2/25 done
# Simulating: 100%|█████████▉| 200/200 [01:03<00:00,  3.14tau/s ]
# 3/25 done
# Simulating: 100%|█████████▉| 200/200 [01:04<00:00,  3.12tau/s ]
# 4/25 done
# Simulating: 100%|█████████▉| 200/200 [01:02<00:00,  3.18tau/s ]
# 5/25 done
# Simulating: 100%|█████████▉| 200/200 [01:02<00:00,  3.20tau/s ]
# 6/25 done
# Simulating: 100%|█████████▉| 200/200 [01:00<00:00,  3.32tau/s ]
# 7/25 done
# Simulating: 100%|█████████▉| 200/200 [00:57<00:00,  3.49tau/s ]
# 8/25 done
# Simulating: 100%|█████████▉| 200/200 [00:56<00:00,  3.54tau/s ]
# 9/25 done
# Simulating: 100%|█████████▉| 200/200 [00:55<00:00,  3.58tau/s ]
# 10/25 done
# Simulating: 100%|█████████▉| 200/200 [00:56<00:00,  3.53tau/s ]
# 11/25 done
# Simulating: 100%|█████████▉| 200/200 [00:55<00:00,  3.58tau/s ]
# 12/25 done
# Simulating: 100%|█████████▉| 200/200 [00:56<00:00,  3.57tau/s ]
# 13/25 done
# Simulating: 100%|█████████▉| 200/200 [00:55<00:00,  3.59tau/s ]
# 14/25 done
# Simulating: 100%|█████████▉| 200/200 [00:54<00:00,  3.67tau/s ]
# 15/25 done
# Simulating: 100%|█████████▉| 200/200 [00:56<00:00,  3.55tau/s ]
# 16/25 done
# Simulating: 100%|█████████▉| 200/200 [00:59<00:00,  3.36tau/s ]
# 17/25 done
# Simulating: 100%|█████████▉| 200/200 [00:58<00:00,  3.40tau/s ]
# 18/25 done
# Simulating: 100%|█████████▉| 200/200 [00:56<00:00,  3.51tau/s ]
# 19/25 done
# Simulating: 100%|█████████▉| 200/200 [00:59<00:00,  3.38tau/s ]
# 20/25 done
# Simulating: 100%|█████████▉| 200/200 [00:56<00:00,  3.55tau/s ]
# 21/25 done
# Simulating: 100%|█████████▉| 200/200 [00:58<00:00,  3.43tau/s ]
# 22/25 done
# Simulating: 100%|█████████▉| 200/200 [00:59<00:00,  3.33tau/s ]
# 23/25 done
# Simulating: 100%|█████████▉| 200/200 [00:58<00:00,  3.40tau/s ]
# 24/25 done
# Simulating: 100%|█████████▉| 200/200 [01:00<00:00,  3.31tau/s ]
# 25/25 done
# --------------------------------------------------------------------------------
# Simulating: 100%|█████████▉| 200/200 [00:17<00:00, 11.70tau/s ]
# 1/25 done
# Simulating: 100%|█████████▉| 200/200 [00:47<00:00,  4.23tau/s ]
# 2/25 done
# Simulating: 100%|█████████▉| 200/200 [00:47<00:00,  4.18tau/s ]
# 3/25 done
# Simulating: 100%|█████████▉| 200/200 [00:48<00:00,  4.13tau/s ]
# 4/25 done
# Simulating: 100%|█████████▉| 200/200 [00:46<00:00,  4.32tau/s ]
# 5/25 done
# Simulating: 100%|█████████▉| 200/200 [00:47<00:00,  4.23tau/s ]
# 6/25 done
# Simulating: 100%|█████████▉| 200/200 [00:45<00:00,  4.36tau/s ]
# 7/25 done
# Simulating: 100%|█████████▉| 200/200 [00:46<00:00,  4.30tau/s ]
# 8/25 done
# Simulating: 100%|█████████▉| 200/200 [00:47<00:00,  4.23tau/s ]
# 9/25 done
# Simulating: 100%|█████████▉| 200/200 [00:47<00:00,  4.24tau/s ]
# 10/25 done
# Simulating: 100%|█████████▉| 200/200 [00:49<00:00,  4.07tau/s ]
# 11/25 done
# Simulating: 100%|█████████▉| 200/200 [00:49<00:00,  4.07tau/s ]
# 12/25 done
# Simulating: 100%|█████████▉| 200/200 [00:51<00:00,  3.91tau/s ]
# 13/25 done
# Simulating: 100%|█████████▉| 200/200 [00:40<00:00,  4.97tau/s ]
# 14/25 done
# Simulating: 100%|█████████▉| 200/200 [00:44<00:00,  4.48tau/s ]
# 15/25 done
# Simulating: 100%|█████████▉| 200/200 [00:48<00:00,  4.15tau/s ]
# 16/25 done
# Simulating: 100%|█████████▉| 200/200 [00:46<00:00,  4.26tau/s ]
# 17/25 done
# Simulating: 100%|█████████▉| 200/200 [00:46<00:00,  4.34tau/s ]
# 18/25 done
# Simulating: 100%|█████████▉| 200/200 [00:48<00:00,  4.10tau/s ]
# 19/25 done
# Simulating: 100%|█████████▉| 200/200 [00:46<00:00,  4.33tau/s ]
# 20/25 done
# Simulating: 100%|█████████▉| 200/200 [00:45<00:00,  4.36tau/s ]
# 21/25 done
# Simulating: 100%|█████████▉| 200/200 [00:48<00:00,  4.08tau/s ]
# 22/25 done
# Simulating: 100%|█████████▉| 200/200 [00:52<00:00,  3.81tau/s ]
# 23/25 done
# Simulating: 100%|█████████▉| 200/200 [00:50<00:00,  3.95tau/s ]
# 24/25 done
# Simulating: 100%|█████████▉| 200/200 [00:48<00:00,  4.11tau/s ]
# 25/25 done

# %%
jj=0
voltages_for_squares=[]
for solutions in solutions_list:
	ii=0
	voltages_list=[]
	voltage_values=np.zeros(len(solutions))
	for solution in solutions:
		voltages_list.append(solution.dynamics.voltage())
		max_idx=voltages_list[ii].shape[0]-1
		voltage_values[ii]=np.mean(voltages_list[ii][max_idx-5000:max_idx])
		print(voltage_values[ii])

		ii+=1
	voltages_for_squares.append(voltages_list)


	plt.plot(currents_list[jj],voltage_values, label=f'{sizes[jj]}$\mu m$')
	jj+=1

plt.legend()
# plt.xlim(0,6)
# plt.ylim(0,1)
# Out:
# 0.0
# 0.08088198970305807
# 0.16207370596369994
# 0.24390422840422413
# 0.32673038969250356
# 0.41096636501652595
# 0.4971251298198027
# 0.585850664316293
# 0.6780392188047365
# 0.7750503828502001
# 0.8793046179179624
# 0.9957230605950983
# 1.1479734632148495
# 3.187820732126121
# 3.4354681061623515
# 3.6811881569797946
# 3.9263223988465294
# 4.171668165401033
# 4.4170117717167905
# 4.662502659278515
# 4.907438286773078
# 5.153191049503752
# 5.398624811851549
# 5.644016305075713
# 5.889166690786313
# 0.0
# 0.0001031631875233448
# 0.00020849034094418207
# 0.00031729167361953877
# 0.00043610331696241575
# 0.000568504149826888
# 0.0007125036050553277
# 0.0008770868990371398
# 0.0010783070766567145
# 0.0013344888592232219
# 0.0016768667868090053
# 0.0022062250292301656
# 0.0034938850925820093
# 2.0103484287121303
# 2.165235280008467
# 2.319907843183275
# 2.474576711507775
# 2.6292275190837557
# 2.783891281284588
# 2.9385473004951024
# 3.0932060414387843
# 3.2478705821263314
# 3.4025345635879596
# 3.5571923778703014
# 3.71184992047413

# %%
import matplotlib.cm as cm
colors=['r','g','b','k']
fig, ax = plt.subplots()

cmap = cm.get_cmap('viridis', len(currents))
norm = plt.Normalize(0, len(currents) - 1)
jj=0

for solutions in solutions_list:
	ii=0
	if jj>=1:
		break
	voltages_list=[]
	for solution in solutions:
		solution.dynamics.voltage()
		
		ii+=1





		ax.plot(solution.dynamics.time,solution.dynamics.voltage(),color=cmap(norm(ii)))
	jj+=1

sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
fig.colorbar(sm, ax=ax, orientation='vertical', label='corriente $\mu A$')
ax.set_xlabel(r'Tiempo ($\tau$)')
ax.set_ylabel('Voltaje ($V_0$)')
# Out:
# C:\Users\cordo\AppData\Local\Temp\ipykernel_9256\3276978076.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('viridis', len(currents))
# Text(0, 0.5, 'Voltaje ($V_0$)')
